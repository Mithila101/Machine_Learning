# %% [markdown]
# <a href="https://colab.research.google.com/github/Mithila101/Machine_Learning/blob/main/Copy_of_KNN_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/loan_approval_dataset.csv')

# %%
df
# Out:
#     Age  Income  Credit_Score  Loan_Amount  Loan_Term  Employment_Years  \
# 0    59   92.96           645        22.86         36                11
# 1    49   83.76           301         7.28         12                 6
# 2    35  108.72           603        44.90         48                 9
# 3    28   67.22           553         6.24         24                18
# 4    41   31.96           752        31.05         60                 6
# ..  ...     ...           ...          ...        ...               ...
# 95   54   31.35           805        20.14         60                 9
# 96   53  112.47           335        34.51         48                 9
# 97   43  107.73           319        22.34         48                18
# 98   44   45.79           620        35.67         48                16
# 99   57   86.00           811        20.33         36                13
#
#     Debt_to_Income_Ratio  Num_Credit_Lines  Has_Coapplicant  Property_Area  \
# ...

# %%
df.head()
# Out:
#    Age  Income  Credit_Score  Loan_Amount  Loan_Term  Employment_Years  \
# 0   59   92.96           645        22.86         36                11
# 1   49   83.76           301         7.28         12                 6
# 2   35  108.72           603        44.90         48                 9
# 3   28   67.22           553         6.24         24                18
# 4   41   31.96           752        31.05         60                 6
#
#    Debt_to_Income_Ratio  Num_Credit_Lines  Has_Coapplicant  Property_Area  \
# 0                  0.20                 7                1              1
# 1                  0.23                 5                0              0
# 2                  0.24                 7                0              2
# 3                  0.20                 9                1              2
# 4                  0.54                 1                1              0
#
#    Loan_Approved
# 0              0
# 1              1
# 2              0
# 3              0
# ...

# %%
print(df.isnull().sum())
print("\nDataset Summary:\n")
print(df.describe())
# Out:
# Age                     0
# Income                  0
# Credit_Score            0
# Loan_Amount             0
# Loan_Term               0
# Employment_Years        0
# Debt_to_Income_Ratio    0
# Num_Credit_Lines        0
# Has_Coapplicant         0
# Property_Area           0
# Loan_Approved           0
# dtype: int64
#
# Dataset Summary:
#
#               Age      Income  Credit_Score  Loan_Amount   Loan_Term  \
# count  100.000000  100.000000    100.000000   100.000000  100.000000
# mean    39.430000   68.367200    560.960000    26.685800   37.080000
# std     11.149358   28.891122    163.876334    13.454275   18.138457
# min     21.000000   20.700000    301.000000     5.690000   12.000000
# 25%     29.000000   43.910000    425.000000    14.570000   24.000000
# 50%     40.500000   69.550000    552.500000    25.245000   36.000000
# 75%     48.000000   92.855000    700.750000    37.332500   51.000000
# max     59.000000  118.570000    846.000000    49.180000   60.000000
#
# ...

# %%
X = df.drop('Loan_Approved', axis=1)
y = df['Loan_Approved']

# %%
print(X)
print(y)
# Out:
#     Age  Income  Credit_Score  Loan_Amount  Loan_Term  Employment_Years  \
# 0    59   92.96           645        22.86         36                11
# 1    49   83.76           301         7.28         12                 6
# 2    35  108.72           603        44.90         48                 9
# 3    28   67.22           553         6.24         24                18
# 4    41   31.96           752        31.05         60                 6
# ..  ...     ...           ...          ...        ...               ...
# 95   54   31.35           805        20.14         60                 9
# 96   53  112.47           335        34.51         48                 9
# 97   43  107.73           319        22.34         48                18
# 98   44   45.79           620        35.67         48                16
# 99   57   86.00           811        20.33         36                13
#
#     Debt_to_Income_Ratio  Num_Credit_Lines  Has_Coapplicant  Property_Area
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=60)

# %%
print(X_train)
# Out:
#     Age  Income  Credit_Score  Loan_Amount  Loan_Term  Employment_Years  \
# 64   34  110.83           817        25.91         24                17
# 52   26   56.36           815        12.14         36                 8
# 35   38  109.61           700         8.64         60                13
# 91   27   58.67           776        14.66         12                 5
# 82   31   24.08           587        30.80         24                 1
# ..  ...     ...           ...          ...        ...               ...
# 15   22   83.64           419        29.17         24                12
# 10   44   72.27           507        42.75         12                 7
# 70   46   87.21           601         5.69         36                17
# 65   43   43.96           398        34.24         24                18
# 77   29   73.58           555        47.49         12                16
#
#     Debt_to_Income_Ratio  Num_Credit_Lines  Has_Coapplicant  Property_Area
# ...

# %%
X_train.shape
# Out:
# (80, 10)

# %%
print(X_test)
# Out:
#     Age  Income  Credit_Score  Loan_Amount  Loan_Term  Employment_Years  \
# 88   25   84.52           545        34.32         60                16
# 4    41   31.96           752        31.05         60                 6
# 79   21  103.53           427        33.64         60                16
# 14   42   23.14           353        18.65         48                 2
# 55   38   45.18           348         9.13         48                 8
# 3    28   67.22           553         6.24         24                18
# 19   22   44.93           553        48.44         12                 5
# 28   35   83.34           460        37.16         12                 2
# 94   32   54.11           824        32.82         12                 4
# 25   47   36.12           452        11.23         48                10
# 48   37  114.29           576        24.61         36                 3
# 69   44   44.21           796        16.74         36                 9
# ...

# %%
print(y_train)
# Out:
# 64    1
# 52    1
# 35    0
# 91    0
# 82    0
#      ..
# 15    1
# 10    1
# 70    1
# 65    0
# 77    0
# Name: Loan_Approved, Length: 80, dtype: int64

# %%
y_train.shape
# Out:
# (80,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.4
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.38      0.56      0.45         9
#            1       0.43      0.27      0.33        11
#
#     accuracy                           0.40        20
#    macro avg       0.41      0.41      0.39        20
# weighted avg       0.41      0.40      0.39        20
#
# Confusion Matrix:
#  [[5 4]
#  [8 3]]

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
TN, FP, FN, TP = cm.ravel()

# %%
print("True Positives (TP):", TP)
print("True Negatives (TN):", TN)
print("False Positives (FP):", FP)
print("False Negatives (FN):", FN)
# Out:
# True Positives (TP): 3
# True Negatives (TN): 5
# False Positives (FP): 4
# False Negatives (FN): 8
